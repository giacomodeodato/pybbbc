# %%
from pybbbc import BBBC021
import numpy as np
import matplotlib.pyplot as plt

# %%
BBBC021.MOA
# Out:
# ['Actin disruptors',
#  'Aurora kinase inhibitors',
#  'Cholesterol-lowering',
#  'DMSO',
#  'DNA damage',
#  'DNA replication',
#  'Eg5 inhibitors',
#  'Epithelial',
#  'Kinase inhibitors',
#  'Microtubule destabilizers',
#  'Microtubule stabilizers',
#  'Protein degradation',
#  'Protein synthesis',
#  'null']

# %%
bbbc021 = BBBC021(moa=['DMSO'])

# %%
#480, 
img = bbbc021[480][0]

# %%
img.shape
# Out:
# (3, 1024, 1280)

# %%
for i in range(3):
    tmp = np.zeros((1024, 1280, 3))
    tmp[:, :, i] = img[i]
    plt.figure(figsize=(12, 10))
    plt.imshow(tmp)
    plt.axis('off')
    plt.show()

# %%
plt.figure(figsize=(12, 10))
plt.imshow(img.transpose(1, 2, 0))
plt.axis('off')
plt.show()
